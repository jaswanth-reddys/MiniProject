# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from ultralytics import YOLO
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from tqdm import tqdm
import time

# ------------------ Config ------------------
model_path = r"C:\Users\Acer\OneDrive\Documents\final\runs\detect\train\weights\best.pt"
images_dir = r"C:\Users\Acer\Downloads\Final\Test\images"
labels_dir = r"C:\Users\Acer\Downloads\Final\Test\labels"
class_names = ['Healthy', 'Rotten']
conf_threshold = 0.3
iou_threshold = 0.5
# --------------------------------------------

model = YOLO(model_path)
y_true = []
y_pred = []

detections_by_class = defaultdict(list)
groundtruths_by_class = defaultdict(list)

image_files = sorted([f for f in os.listdir(images_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
start = time.time()

print("🔍 Running inference on images...")

for image_file in tqdm(image_files, disable=True):  # Disable the progress bar output
    img_path = os.path.join(images_dir, image_file)
    label_path = os.path.join(labels_dir, os.path.splitext(image_file)[0] + ".txt")
    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    # Suppress the inference logs by setting verbose=False
    results = model.predict(source=img, conf=conf_threshold, iou=0.5, stream=False, verbose=False)
    
    boxes = results[0].boxes
    pred_classes = boxes.cls.cpu().numpy().astype(int) if boxes.cls is not None else []
    pred_confs = boxes.conf.cpu().numpy() if boxes.conf is not None else []
    pred_bboxes = boxes.xyxy.cpu().numpy() if boxes.xyxy is not None else []

    for cls, conf, box in zip(pred_classes, pred_confs, pred_bboxes):
        detections_by_class[cls].append({'image_id': image_file, 'conf': conf, 'box': box.tolist()})

    gt_classes = []
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            for line in f:
                cls_id, x, y, bw, bh = map(float, line.strip().split())
                cls_id = int(cls_id)
                x1 = (x - bw / 2) * w
                y1 = (y - bh / 2) * h
                x2 = (x + bw / 2) * w
                y2 = (y + bh / 2) * h
                gt_box = [x1, y1, x2, y2]
                groundtruths_by_class[cls_id].append({'image_id': image_file, 'box': gt_box, 'used': False})
                gt_classes.append(cls_id)

        # Confusion matrix part
        if len(gt_classes) == 0:
            continue
        if len(pred_classes) == 0:
            for gt in gt_classes:
                y_true.append(gt)
                y_pred.append(len(class_names))  # no detection
        else:
            for gt in gt_classes:
                y_true.append(gt)
                y_pred.append(pred_classes[0])
    else:
        print(f"⚠️ Missing label: {image_file}")

end = time.time()

# ---------------- mAP@0.5 Calculation ----------------

def iou(boxA, boxB):
    xA, yA = max(boxA[0], boxB[0]), max(boxA[1], boxB[1])
    xB, yB = min(boxA[2], boxB[2]), min(boxA[3], boxB[3])
    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    union = float(boxAArea + boxBArea - interArea)
    return interArea / union if union > 0 else 0

def compute_ap(recalls, precisions):
    ap = 0.0
    for t in np.linspace(0, 1, 11):
        if np.any(recalls >= t):
            ap += np.max(precisions[recalls >= t])
    return ap / 11

average_precisions = []
for cls_id in range(len(class_names)):
    detections = sorted(detections_by_class[cls_id], key=lambda x: -x['conf'])
    gts = groundtruths_by_class[cls_id]
    for g in gts:
        g['used'] = False

    TP = np.zeros(len(detections))
    FP = np.zeros(len(detections))
    n_gt = len(gts)

    for i, det in enumerate(detections):
        matched = False
        for gt in gts:
            if gt['image_id'] == det['image_id'] and not gt['used']:
                iou_val = iou(det['box'], gt['box'])
                if iou_val >= iou_threshold:
                    TP[i] = 1
                    gt['used'] = True
                    matched = True
                    break
        if not matched:
            FP[i] = 1

    cum_TP = np.cumsum(TP)
    cum_FP = np.cumsum(FP)
    recalls = cum_TP / n_gt if n_gt else np.zeros_like(cum_TP)
    precisions = cum_TP / (cum_TP + cum_FP + 1e-6)
    ap = compute_ap(recalls, precisions)
    average_precisions.append(ap)
    print(f"AP@0.5 for {class_names[cls_id]}: {ap:.4f}")

mAP50 = np.mean(average_precisions)
print(f"\n✅ mAP@0.5: {mAP50:.4f}")

# ---------------- Confusion Matrix ----------------

label_list = class_names + ['no_detection']
y_pred = [p if p < len(class_names) else len(class_names) for p in y_pred]

if len(y_true) == 0:
    print("⚠️ No matched labels! Check label format or filenames.")
else:
    cm = confusion_matrix(y_true, y_pred, labels=list(range(len(label_list))))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_list)
    disp.plot(cmap='Blues', xticks_rotation=45, values_format='d')
    plt.title("Confusion Matrix")
    plt.grid(False)
    plt.tight_layout()
    plt.show()

    acc = accuracy_score(y_true, y_pred)
    print(f"✅ Accuracy: {acc:.2%}")
    print(f"🕒 Evaluation Time: {end - start:.2f} seconds")
# Out:
# 🔍 Running inference on images...
# ⚠️ Missing label: freshBanana (1).png
# ⚠️ Missing label: freshBanana (102).png
# ⚠️ Missing label: freshBanana (112).png
# ⚠️ Missing label: freshBanana (114).png
# ⚠️ Missing label: freshBanana (116).png
# ⚠️ Missing label: freshBanana (12).jpg
# ⚠️ Missing label: freshBanana (120).jpg
# ⚠️ Missing label: freshBanana (125).jpg
# ⚠️ Missing label: freshBanana (133).jpg
# ⚠️ Missing label: freshBanana (135).jpg
# ⚠️ Missing label: freshBanana (136).png
# ⚠️ Missing label: freshBanana (141).png
# ⚠️ Missing label: freshBanana (152).png
# ⚠️ Missing label: freshBanana (155).jpg
# ⚠️ Missing label: freshBanana (156).png
# ⚠️ Missing label: freshBanana (158).png
# ⚠️ Missing label: freshBanana (163).jpg
# ⚠️ Missing label: freshBanana (167).png
# ⚠️ Missing label: freshBanana (171).jpg
# ⚠️ Missing label: freshBanana (174).jpg
# ⚠️ Missing label: freshBanana (178).png
# ⚠️ Missing label: freshBanana (181).jpg
# ⚠️ Missing label: freshBanana (182).png
# ⚠️ Missing label: freshBanana (25).jpg
# ⚠️ Missing label: freshBanana (29).jpg
# ⚠️ Missing label: freshBanana (30).jpg
# ⚠️ Missing label: freshBanana (33).jpg
# ⚠️ Missing label: freshBanana (36).jpg
# ⚠️ Missing label: freshBanana (37).png
# ⚠️ Missing label: freshBanana (4).png
# ⚠️ Missing label: freshBanana (46).png
# ⚠️ Missing label: freshBanana (51).jpg
# ⚠️ Missing label: freshBanana (53).jpg
# ⚠️ Missing label: freshBanana (61).jpg
# ⚠️ Missing label: freshBanana (65).png
# ⚠️ Missing label: freshBanana (83).png
# ⚠️ Missing label: freshBanana (84).jpg
# ⚠️ Missing label: freshBanana (88).png
# ⚠️ Missing label: freshBanana (91).jpg
# ⚠️ Missing label: freshBanana (93).jpg
# ⚠️ Missing label: freshBanana (99).png
# ⚠️ Missing label: freshCarrot (1).png
# ⚠️ Missing label: freshCarrot (10).jpeg
# ⚠️ Missing label: freshCarrot (3).jpg
# ⚠️ Missing label: freshCarrot (6).jpg
# ⚠️ Missing label: freshCucumber (2).jpg
# ⚠️ Missing label: freshCucumber (4).jpeg
# ⚠️ Missing label: freshCucumber (5).jpeg
# ⚠️ Missing label: freshMango (100).png
# ⚠️ Missing label: freshMango (103).jpg
# ⚠️ Missing label: freshMango (105).png
# ⚠️ Missing label: freshMango (106).png
# ⚠️ Missing label: freshMango (112).jpg
# ⚠️ Missing label: freshMango (119).jpg
# ⚠️ Missing label: freshMango (120).jpg
# ⚠️ Missing label: freshMango (128).png
# ⚠️ Missing label: freshMango (129).png
# ⚠️ Missing label: freshMango (13).png
# ⚠️ Missing label: freshMango (131).jpg
# ⚠️ Missing label: freshMango (134).png
# ⚠️ Missing label: freshMango (138).png
# ⚠️ Missing label: freshMango (141).jpg
# ⚠️ Missing label: freshMango (150).jpg
# ⚠️ Missing label: freshMango (151).jpg
# ⚠️ Missing label: freshMango (154).jpg
# ⚠️ Missing label: freshMango (156).png
# ⚠️ Missing label: freshMango (158).png
# ⚠️ Missing label: freshMango (162).jpg
# ⚠️ Missing label: freshMango (163).png
# ⚠️ Missing label: freshMango (170).jpg
# ⚠️ Missing label: freshMango (174).jpg
# ⚠️ Missing label: freshMango (178).jpg
# ⚠️ Missing label: freshMango (185).jpg
# ⚠️ Missing label: freshMango (189).png
# ⚠️ Missing label: freshMango (191).jpg
# ⚠️ Missing label: freshMango (2).png
# ⚠️ Missing label: freshMango (202).png
# ⚠️ Missing label: freshMango (204).png
# ⚠️ Missing label: freshMango (205).jpg
# ⚠️ Missing label: freshMango (207).jpg
# ⚠️ Missing label: freshMango (21).jpg
# ⚠️ Missing label: freshMango (211).jpg
# ⚠️ Missing label: freshMango (213).png
# ⚠️ Missing label: freshMango (214).png
# ⚠️ Missing label: freshMango (216).png
# ⚠️ Missing label: freshMango (22).png
# ⚠️ Missing label: freshMango (23).png
# ⚠️ Missing label: freshMango (24).jpg
# ⚠️ Missing label: freshMango (29).jpg
# ⚠️ Missing label: freshMango (3).png
# ⚠️ Missing label: freshMango (31).jpg
# ⚠️ Missing label: freshMango (33).jpg
# ⚠️ Missing label: freshMango (37).jpg
# ⚠️ Missing label: freshMango (41).jpg
# ⚠️ Missing label: freshMango (42).jpg
# ⚠️ Missing label: freshMango (43).jpg
# ⚠️ Missing label: freshMango (46).png
# ⚠️ Missing label: freshMango (58).png
# ⚠️ Missing label: freshMango (59).png
# ⚠️ Missing label: freshMango (63).png
# ⚠️ Missing label: freshMango (7).png
# ⚠️ Missing label: freshMango (75).png
# ⚠️ Missing label: freshMango (78).jpg
# ⚠️ Missing label: freshMango (92).jpg
# ⚠️ Missing label: freshOrange (101).jpg
# ⚠️ Missing label: freshOrange (102).png
# ⚠️ Missing label: freshOrange (103).png
# ⚠️ Missing label: freshOrange (106).png
# ⚠️ Missing label: freshOrange (110).png
# ⚠️ Missing label: freshOrange (111).png
# ⚠️ Missing label: freshOrange (117).png
# ⚠️ Missing label: freshOrange (119).jpg
# ⚠️ Missing label: freshOrange (12).png
# ⚠️ Missing label: freshOrange (122).png
# ⚠️ Missing label: freshOrange (125).jpg
# ⚠️ Missing label: freshOrange (135).png
# ⚠️ Missing label: freshOrange (141).png
# ⚠️ Missing label: freshOrange (146).png
# ⚠️ Missing label: freshOrange (154).png
# ⚠️ Missing label: freshOrange (156).png
# ⚠️ Missing label: freshOrange (159).png
# ⚠️ Missing label: freshOrange (162).png
# ⚠️ Missing label: freshOrange (163).png
# ⚠️ Missing label: freshOrange (166).jpg
# ⚠️ Missing label: freshOrange (168).jpg
# ⚠️ Missing label: freshOrange (172).png
# ⚠️ Missing label: freshOrange (176).png
# ⚠️ Missing label: freshOrange (178).png
# ⚠️ Missing label: freshOrange (183).png
# ⚠️ Missing label: freshOrange (185).png
# ⚠️ Missing label: freshOrange (192).png
# ⚠️ Missing label: freshOrange (193).png
# ⚠️ Missing label: freshOrange (196).jpg
# ⚠️ Missing label: freshOrange (197).jpg
# ⚠️ Missing label: freshOrange (201).jpg
# ⚠️ Missing label: freshOrange (205).jpg
# ⚠️ Missing label: freshOrange (216).png
# ⚠️ Missing label: freshOrange (225).jpg
# ⚠️ Missing label: freshOrange (23).jpg
# ⚠️ Missing label: freshOrange (230).jpg
# ⚠️ Missing label: freshOrange (234).png
# ⚠️ Missing label: freshOrange (237).jpg
# ⚠️ Missing label: freshOrange (238).jpg
# ⚠️ Missing label: freshOrange (240).png
# ⚠️ Missing label: freshOrange (241).png
# ⚠️ Missing label: freshOrange (244).png
# ⚠️ Missing label: freshOrange (246).jpg
# ⚠️ Missing label: freshOrange (248).png
# ⚠️ Missing label: freshOrange (249).png
# ⚠️ Missing label: freshOrange (251).jpg
# ⚠️ Missing label: freshOrange (255).png
# ⚠️ Missing label: freshOrange (257).jpg
# ⚠️ Missing label: freshOrange (26).jpg
# ⚠️ Missing label: freshOrange (260).png
# ⚠️ Missing label: freshOrange (270).png
# ⚠️ Missing label: freshOrange (279).png
# ⚠️ Missing label: freshOrange (284).jpg
# ⚠️ Missing label: freshOrange (287).png
# ⚠️ Missing label: freshOrange (289).png
# ⚠️ Missing label: freshOrange (293).jpg
# ⚠️ Missing label: freshOrange (299).jpg
# ⚠️ Missing label: freshOrange (3).jpg
# ⚠️ Missing label: freshOrange (30).png
# ⚠️ Missing label: freshOrange (31).jpg
# ⚠️ Missing label: freshOrange (36).png
# ⚠️ Missing label: freshOrange (38).png
# ⚠️ Missing label: freshOrange (45).png
# ⚠️ Missing label: freshOrange (48).png
# ⚠️ Missing label: freshOrange (5).png
# ⚠️ Missing label: freshOrange (51).png
# ⚠️ Missing label: freshOrange (73).png
# ⚠️ Missing label: freshOrange (77).png
# ⚠️ Missing label: freshOrange (79).png
# ⚠️ Missing label: freshOrange (87).png
# ⚠️ Missing label: freshOrange (92).png
# ⚠️ Missing label: freshOrange (94).png
# ⚠️ Missing label: freshOrange (98).jpg
# ⚠️ Missing label: freshPepper (1).jpeg
# ⚠️ Missing label: freshPepper (4).png
# ⚠️ Missing label: freshPotato (3).jpeg
# ⚠️ Missing label: freshTomato (104).png
# ⚠️ Missing label: freshTomato (107).png
# ⚠️ Missing label: freshTomato (108).jpg
# ⚠️ Missing label: freshTomato (109).png
# ⚠️ Missing label: freshTomato (110).jpg
# ⚠️ Missing label: freshTomato (121).jpg
# ⚠️ Missing label: freshTomato (122).jpg
# ⚠️ Missing label: freshTomato (126).jpg
# ⚠️ Missing label: freshTomato (127).png
# ⚠️ Missing label: freshTomato (13).png
# ⚠️ Missing label: freshTomato (132).png
# ⚠️ Missing label: freshTomato (134).jpg
# ⚠️ Missing label: freshTomato (136).png
# ⚠️ Missing label: freshTomato (137).png
# ⚠️ Missing label: freshTomato (139).jpg
# ⚠️ Missing label: freshTomato (141).jpg
# ⚠️ Missing label: freshTomato (147).png
# ⚠️ Missing label: freshTomato (148).jpg
# ⚠️ Missing label: freshTomato (149).jpg
# ⚠️ Missing label: freshTomato (152).png
# ⚠️ Missing label: freshTomato (156).png
# ⚠️ Missing label: freshTomato (159).png
# ⚠️ Missing label: freshTomato (169).jpg
# ⚠️ Missing label: freshTomato (172).png
# ⚠️ Missing label: freshTomato (179).png
# ⚠️ Missing label: freshTomato (199).png
# ⚠️ Missing label: freshTomato (20).jpg
# ⚠️ Missing label: freshTomato (202).png
# ⚠️ Missing label: freshTomato (209).jpg
# ⚠️ Missing label: freshTomato (21).png
# ⚠️ Missing label: freshTomato (220).png
# ⚠️ Missing label: freshTomato (229).jpg
# ⚠️ Missing label: freshTomato (23).png
# ⚠️ Missing label: freshTomato (24).jpg
# ⚠️ Missing label: freshTomato (240).jpg
# ⚠️ Missing label: freshTomato (247).png
# ⚠️ Missing label: freshTomato (250).jpg
# ⚠️ Missing label: freshTomato (251).png
# ⚠️ Missing label: freshTomato (256).png
# ⚠️ Missing label: freshTomato (260).png
# ⚠️ Missing label: freshTomato (264).jpg
# ⚠️ Missing label: freshTomato (273).jpg
# ⚠️ Missing label: freshTomato (278).jpg
# ⚠️ Missing label: freshTomato (28).jpg
# ⚠️ Missing label: freshTomato (281).jpg
# ⚠️ Missing label: freshTomato (29).jpg
# ⚠️ Missing label: freshTomato (34).jpg
# ⚠️ Missing label: freshTomato (39).jpg
# ⚠️ Missing label: freshTomato (4).jpg
# ⚠️ Missing label: freshTomato (42).jpg
# ⚠️ Missing label: freshTomato (45).png
# ⚠️ Missing label: freshTomato (61).png
# ⚠️ Missing label: freshTomato (67).jpg
# ⚠️ Missing label: freshTomato (69).jpg
# ⚠️ Missing label: freshTomato (70).png
# ⚠️ Missing label: freshTomato (76).png
# ⚠️ Missing label: freshTomato (81).png
# ⚠️ Missing label: freshTomato (85).jpg
# ⚠️ Missing label: freshTomato (88).jpg
# ⚠️ Missing label: freshTomato (89).jpg
# ⚠️ Missing label: freshTomato (9).jpg
# ⚠️ Missing label: freshTomato (99).jpg
# ⚠️ Missing label: rottenApple (2).jpg
# ⚠️ Missing label: rottenMango (11).jpg
# ⚠️ Missing label: rottenMango (13).jpeg
# ⚠️ Missing label: rottenMango (2).jpg
# ⚠️ Missing label: rottenMango (5).jpg
# ⚠️ Missing label: rottenStrawberry (11).jpg
# ⚠️ Missing label: rottenStrawberry (12).jpg
# ⚠️ Missing label: rottenStrawberry (2).jpg
# ⚠️ Missing label: rottenStrawberry (22).jpg
# ⚠️ Missing label: rottenStrawberry (24).jpeg
# ⚠️ Missing label: rottenStrawberry (3).jpeg
# ⚠️ Missing label: rottenTomato (5).jpeg
# ⚠️ Missing label: rottenTomato (8).jpg
# AP@0.5 for Healthy: 0.5051
# AP@0.5 for Rotten: 0.5526
#
# ✅ mAP@0.5: 0.5289
# ✅ Accuracy: 91.01%
# 🕒 Evaluation Time: 863.16 seconds
